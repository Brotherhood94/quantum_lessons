# %%
from scipy import fftpack
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# Amplitude (A) is the maximum height of the sine function from its zero base.
#
# Frequency (f) is the number of complete cycles in a set period. When working in Hertz (Hz), frequency is defined as the number of complete cycles within 1 second.

# %%
f1 = 3 # frequency
f2 = 9 # frequency


Fs = 100 # sampling rate
duration = 1

time = np.arange(0, duration, 1/Fs) 
y_time_domain = np.sin(2 * np.pi * f1 * time) + np.sin(2 * np.pi * f2 * time) #source


# Perform Fourier transform using scipy
y_ftt = fftpack.fft(y_time_domain)

n = np.size(time)
fr = Fs * np.linspace(0, duration, int(n/2))
y_freq_domain = 2/n * abs(y_ftt[0:np.size(fr)])


fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax[0].plot(time, y_time_domain)    # plot time series
ax[1].stem(fr, y_freq_domain) # plot freq domain
# Out:
# <StemContainer object of 3 artists>

# %%
y_ftt_filterd_f1 = y_ftt.copy()
y_ftt_filterd_f2 = y_ftt.copy()

for i in range(len(y_ftt)):
    if y_ftt_filterd_f1[i] != y_ftt[f1]:
        y_ftt_filterd_f1[i] = 0
        
for i in range(len(y_ftt)):
    if y_ftt_filterd_f2[i] != y_ftt[f2]:
        y_ftt_filterd_f2[i] = 0
        
y_freq_domain_filtered_f1 = 2/n * abs(y_ftt_filterd_f1[0:np.size(fr)])
y_freq_domain_filtered_f2 = 2/n * abs(y_ftt_filterd_f2[0:np.size(fr)])
        
y_iftt_filterd_f1 = fftpack.ifft(y_ftt_filterd_f1)
y_iftt_filterd_f2 = fftpack.ifft(y_ftt_filterd_f2)

fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,5))
ax[0].stem(fr, y_freq_domain_filtered_f1)  # plot freq domain
ax[1].plot(time, y_iftt_filterd_f1)    # plot time series

ax[2].stem(fr, y_freq_domain_filtered_f2)  # plot freq domain
ax[3].plot(time, y_iftt_filterd_f2)    # plot time series
# Out:
# /Users/alessandro/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /Users/alessandro/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
from scipy.io.wavfile import read, write

Fs, data = read('test_mixdown.wav')

data = stereo[:, 0]

print(Fs)
print(data)

duration = len(data)/Fs
print(duration)

time = np.arange(0, duration, 1/Fs)

print(time)

plt.plot(range(len(data)), data)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('test_mixdown.wav')
plt.show()
# Out:
# /var/folders/37/8ckg6c8n10n94f4dv2xdfll00000gn/T/ipykernel_67089/1424031145.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   Fs, data = read('test_mixdown.wav')
# 48000
# [-2.9872674e-24 -2.5895023e-04 -4.3158373e-04 ... -9.7949393e-02
#  -8.6289927e-02 -7.4406065e-02]
# 8.8951875
# [0.00000000e+00 2.08333333e-05 4.16666667e-05 ... 8.89514583e+00
#  8.89516667e+00 8.89518750e+00]

# %%
# Perform Fourier transform using scipy
y_ftt = fftpack.fft(data)

n = np.size(time)

fr = Fs * np.linspace(0, duration, int(n/2))
print(len(fr))

y_freq_domain = 2/n * abs(y_ftt[0:np.size(fr)])
print(len(y_freq_domain))

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax[0].plot(range(len(data)), data)    # plot time series
ax[1].stem(fr, y_freq_domain) # plot freq domain
# Out:
# 213485
# 213485
# <StemContainer object of 3 artists>

# %%
for freq in range(len(y_ftt)):
    if freq > 20000:
        y_ftt[freq] = 0

print(y_ftt)
y_freq_domain = 2/n * abs(y_ftt[0:np.size(fr)])
        
y_iftt = fftpack.ifft(y_ftt)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax[0].stem(fr, y_freq_domain)  # plot freq domain
ax[1].plot(range(len(y_iftt)), y_iftt)    # plot time series
# Out:
# [-19.482485  -0.j           0.5599841+25.80591j
#  -10.784906  -0.97405916j ...   0.        +0.j
#    0.        +0.j           0.        +0.j        ]
# /Users/alessandro/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
y_iftt2 = np.asarray(y_iftt, dtype=np.float64)
print(y_iftt2)
write('/Users/alessandro/Github/quantum_lessons/test_mixdown_filtered.wav', Fs, y_iftt2)
# Out:
# [-0.02295212 -0.01761299 -0.01253909 ... -0.0379592  -0.0333825
#  -0.02829711]

# %% [markdown]
# # Quantum Fourier Transform

# %%
import math
from numpy import pi

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.circuit.library import PhaseEstimation, PhaseGate, CPhaseGate, HGate, XGate, SwapGate
from qiskit.visualization import plot_histogram, plot_bloch_multivector

# %%
def QFT(n):
    q = QuantumRegister(n, 'q')
    qft_circuit = QuantumCircuit(q, name='QFT '+str(n))
    
    for i in range(len(q))[::-1]:
        qft_circuit.append(HGate(), [q[i]])
        
        for k in range(i):
            controlled_phase_gate = CPhaseGate(pi/(2**(k-i)))
            qft_circuit.append(controlled_phase_gate, [q[k], q[i]])
        qft_circuit.barrier()

    for i in range(math.floor(len(q)/2)):
        qft_circuit.append(SwapGate(), [q[i], q[len(q)-i-1]])
    qft_circuit.barrier()

    return qft_circuit

# %%
def Inverse_QFT(n):
    q = QuantumRegister(n, 'q')
    qft_circuit = QuantumCircuit(q, name='Inverse_QFT '+str(n))
    
    for i in range(math.floor(len(q)/2)):
        qft_circuit.append(SwapGate(), [q[i], q[len(q)-i-1]])


    for i in range(len(q)):
        for j in range(i):
            controlled_phase_gate = CPhaseGate(-pi/(2**(i-j)))
            qft_circuit.append(controlled_phase_gate, [q[j], q[i]])
        qft_circuit.append(HGate(), [q[i]])
        qft_circuit.barrier()
    
    return qft_circuit

# %%
def encode_bin_value(bin_value):
    q = QuantumRegister(len(bin_value))
    qc_value = QuantumCircuit(q, name='encode: '+bin_value)
    
    for i in range(len(bin_value)):
        if int(bin_value[i]):
            qc_value.append(XGate(), [q[i]])

    return qc_value.reverse_bits()

# %%
n = 4

f = QuantumRegister(n, 'f')

qft_circuit = QuantumCircuit(f, name='QFT '+str(n))

bin_value = '0001'
qft_circuit.append(encode_bin_value(bin_value), f[0:])

qft_circuit.barrier()
    
qft_circuit.append(QFT(len(f)), f[0:])
#qft_circuit.append(Inverse_QFT(len(f)), f[0:])

    
qft_circuit.barrier()

qft_circuit.decompose().draw('mpl', fold=30)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(qft_circuit, simulator)
statevector = job.result().get_statevector()
print(bin_value)
plot_bloch_multivector(statevector, reverse_bits=True)

# %%
import time
from IPython.display import clear_output
from IPython.display import display
from qiskit.visualization import plot_bloch_vector,plot_bloch_multivector
# %matplotlib inline

n = 16
digits = int(math.log2(n))

binary_values = []

for val in range(n):
    bin_str_pattern = '{:0%sb}' % digits
    bin_value = bin_str_pattern.format(val)
    binary_values.append(bin_value)

print(binary_values)

simulator = Aer.get_backend('statevector_simulator')

for bin_value in binary_values:
    comp_base_circuit = QuantumCircuit(digits)
    comp_base_circuit.append(encode_bin_value(bin_value), range(digits))
    comp_base_statevector = execute(comp_base_circuit, simulator).result().get_statevector()


    fourier_base_circuit = QuantumCircuit(digits)
    fourier_base_circuit.append(encode_bin_value(bin_value), range(digits))
    fourier_base_circuit.append(QFT(digits), range(digits))
    fourier_base_statevector = execute(fourier_base_circuit, simulator).result().get_statevector()
    
    clear_output(wait=True)
    display(plot_bloch_multivector(comp_base_statevector, title=bin_value, reverse_bits=True))
    display(plot_bloch_multivector(fourier_base_statevector, reverse_bits=True))
    time.sleep(2)

# %% [markdown]
# # QUANTUM PHASE ESTIMATION

# %%
import math
from numpy import pi

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.circuit.library import PhaseEstimation, PhaseGate, CPhaseGate
from qiskit.visualization import plot_histogram

# %% [markdown]
# ## Set Up: angle & counting qubits

# %%
#Here you can insert the phase (=angle), you wish to encode.

angle = pi/4 #The phase angle we wish to encode

actual_phase = angle/(2*pi)  #This is the actual phase rotation (We use this value to check the answer)

precision = 3 #precision (a.k.a counting qubits)

# %% [markdown]
# ## STEP 1

# %%
cq = QuantumRegister(precision, 'counting_qubits')
psi = QuantumRegister(1, 'psi')
cc = ClassicalRegister(precision, 'precision')
circuit = QuantumCircuit(cq, psi, cc)

circuit.draw(output='mpl')

# %% [markdown]
# ## STEP 2

# %%
#Superpose counting qubits
circuit.h(cq)

# |psi> = 0 --> X|psi> = 1 (eigenvector of any PhaseGate)
circuit.x(psi)
circuit.barrier()

circuit.draw(output='mpl')

# %% [markdown]
# ## STEP 3

# %%
##----- Encoding in the Fourier Basis the phase -----#
for i in range(len(cq)):
    unitary = CPhaseGate(angle*(2**i))
    circuit.append(unitary, [cq[i], psi])
        
circuit.barrier()
circuit.draw(output='mpl')

# %% [markdown]
# ## STEP 4

# %%
#----- Inverse QFT -----#
circuit.append(Inverse_QFT(len(cq)), cq[0:])

circuit.measure(cq, cc)
circuit.draw(output='mpl')

# %% [markdown]
# # Simulate

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots=8192)
counts = job.result().get_counts()

print("Phase estimation output")
print("-----------------------")

a = counts.most_frequent()
print("Most frequent measurement:", a, "\n")
bin_a = int(a,2) #Converts the binary value to an integer

#(Note that the QPE outputs |2^(len(cq))*angle). So. to obtaing the angle (phase) --> bin_a/(2**len(cq))
phase = bin_a/(2**len(cq)) #The calculation used to estimate the phase 

print("ESTIMATED: ", phase)
print("ACTUAL: ", actual_phase) 

print("Error: ", abs(actual_phase - phase))  # <-- Error != 0, if the number of counting qubits (precision) is not enough to represent the phase in the computational basis

# %%
plot_histogram(counts, title="Value")

# %% [markdown]
# # QISKIT LIBRARY

# %%
#--------------STEP 1--------------
cq = QuantumRegister(precision, 'counting_qubits')
psi = QuantumRegister(1, 'psi')
cc = ClassicalRegister(precision, 'precision')
circuit_qiskit = QuantumCircuit(cq, psi, cc)


#--------------STEP 2--------------
# |psi> = 0 --> X|psi> = 1 (eigenvector of any PhaseGate)
circuit_qiskit.x(psi)
circuit_qiskit.barrier()



#------------STEP 3 & 4------------
unitary = PhaseGate(angle*(2**i))
circuit_qiskit.append(PhaseEstimation(len(cq), unitary), cq[0:]+psi[0:])
circuit_qiskit.barrier()

circuit_qiskit.measure(cq, cc)


circuit_qiskit.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_qiskit, simulator, shots=8192)
counts = job.result().get_counts()

print("Phase estimation output")
print("-----------------------")

a = counts.most_frequent()
print("Most frequeant measurement:", a, "\n")
bin_a = int(a,2) #Converts the binary value to an integer

#(Note that the QPE outputs |2^(len(cq))*angle). So. to obtaing the angle (phase) --> bin_a/(2**len(cq))
phase = bin_a/(2**len(cq)) #The calculation used to estimate the phase 

print("ESTIMATED: ", phase)
print("ACTUAL: ", actual_phase) 

print("Error: ", abs(actual_phase - phase))  # <-- Error != 0, if the number of counting qubits (precision) is not enough to represent the phase in the computational basis
